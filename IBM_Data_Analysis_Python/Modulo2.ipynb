# %% [markdown]
# # Módulo 2
#
# **Materia:** Ciencia y Analítica de Datos
#
# **Curso:** IBM Data Analysis with Python
#
# **Alumno:** Víctor Alejandro Regueira Romero - A01794404
#
# ---

# %% [markdown]
# ## IBM Curso

# %% [markdown]
# ### Data-preprocessing

# %% [markdown]
# Missing Values
# N/A, ?, 0, celda vacía.
#
# * Podemos eliminar los registros por completo.
# * Remover la columna o variable
# * Imputar los datos siguiendo una estrategia (promedio, media, moda)

# %% [markdown]
# df.dropna() Elimina todos los registros.
#
# * axis 0 = fila completa
# * axis 1 = columna completa
#
# df.dropna(subset=['price'] ,axis=0, inplace=True)
# df = df.dropna(subset=['price'], axis = 0)

# %% [markdown]
# **Reemplazar los valores**
# ![imagen.png](attachment:cee61747-b3ba-44d6-8fad-b24fd755092f.png)

# %% [markdown]
# ### Data Formatting
#
# Mantener un estándar en el formato de las entradas
#
# ![imagen.png](attachment:72069129-0292-4ba9-aa85-4e465eb6c939.png)

# %% [markdown]
# ![imagen.png](attachment:9f0059c4-860c-454e-b38f-09a939db13b1.png)

# %% [markdown]
# Data types
# * Objects
# * Int64
# * Float64

# %%
#df.datatypes() Leer tipos de datos
#df.astype() Cambiat el tipo de dato

# %% [markdown]
# ### Data Normalization

# %% [markdown]
# ![imagen.png](attachment:22692331-5cd0-4838-98c6-80ae191ed422.png)

# %% [markdown]
# ### Binning
#
# Agregar etiquetas a variables numéricas para convertirlas en categóricas
#
# ![imagen.png](attachment:5dfb8579-57e3-4a95-927a-4c0154213e77.png)

# %% [markdown]
# De esta forma es más claro ver la información y la distrivución de los datos

# %% [markdown]
# ### Categorical into quantitive
#
# No podemos hacer análisis con objetos/strings
#
# * Agregar dummy variables para cada categoría
# * Asignarlos con 0 y 1 en cada categoría

# %% [markdown]
# ![imagen.png](attachment:09f6e28b-513b-45b5-a826-3440ba1f8d2e.png)

# %% [markdown]
# ## Labs

# %% [markdown]
# [DA0101EN-Review-Introduction](https://github.com/PosgradoMNA/actividades-de-aprendizaje-VictorRegueira/blob/main/IBM_Data_Analysis_Python/Labs/DA0101EN-Review-Introduction.jupyterlite.ipynb)

# %% [markdown]
# ## Graded Review Questions
