# %% [markdown]
# # Módulo 5 Model Evaluation and Refinement
#
# **Materia:** Ciencia y Analítica de Datos
#
# **Curso:** IBM Data Analysis with Python
#
# **Alumno:** Víctor Alejandro Regueira Romero - A01794404
#
# ---

# %% [markdown]
# ## IBM Curso

# %% [markdown]
# ### Model Evaluation
#
# Debemos de **separar** los datos en dos conjuntos: Trainning/Testing, usando una distribución de 80-20, 90-10, etc respectivamente. Esto permitirá entrenar el modelo y luego aplicarlos.
#
# Para esto usamos la función train_test_split(x_data, y_data, test_size=0.2,random_state=0)
#
# ![imagen.png](attachment:ddd6ccd6-2480-4818-b4d3-3d32f61e8664.png)

# %% [markdown]
# ![imagen.png](attachment:cf925864-8eb5-4146-b0f6-1ad8ffc7cd36.png)

# %% [markdown]
# ### Overfitting, Underfitting and Model Selection
#
# Se debe de aumnetar la potencia del polinomio para ir acercando el modelo a nuestro resultado esperado
#
# ![imagen.png](attachment:3938b812-b5ee-4704-8dce-88eb944d82cf.png)

# %% [markdown]
# ### Ridge Regression
#
# Previene el Overfitting
#
# Siempre tendrems outliers que afecan la estimación de nuestro modelo
# ![imagen.png](attachment:7cf199c0-75ff-476e-b465-27ba135721cb.png)

# %% [markdown]
# ### Grid Search
#
# Encontrar hiperparámetros para las funciones que usamos, como lo es el Ridge Regression

# %% [markdown]
# ![imagen.png](attachment:4223e207-69d6-4290-9167-84fe4792a47d.png)

# %% [markdown]
# ## Labs

# %% [markdown]
# [DA0101EN-4-Review-Model-Development]https://github.com/PosgradoMNA/actividades-de-aprendizaje-VictorRegueira/blob/main/IBM_Data_Analysis_Python/Labs/DA0101EN-5-Review-Model-Evaluation-and-Refinement.jupyterlite.ipynb)

# %% [markdown]
# ## Graded Review Questions

# %% [markdown]
# ![imagen.png](attachment:e84d6fb6-57b2-4748-81d6-7cda944b91c5.png)

# %% [markdown]
# ![imagen.png](attachment:1aa3ca25-c989-4f8e-9fbb-25a9112a244a.png)
