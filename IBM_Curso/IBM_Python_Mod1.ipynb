# %% [markdown]
# # Curso de IBM

# %% [markdown]
# ## First Program

# %%
print('Hello Python')
# Out:
# Hello Python

# %%
print("Hello\nWorld!")
# Out:
# Hello
# World!

# %%
# print('Hello World!')

# %% [markdown]
# ## Python Type

# %%
type(int(1.0))
# Out:
# int

# %%
bool(1)
# Out:
# True

# %% [markdown]
# ## Expressions and Variables

# %%
x, y, z = ["hola", 24, 50.1]
type(x)
type(y)
type(z)
# Out:
# float
