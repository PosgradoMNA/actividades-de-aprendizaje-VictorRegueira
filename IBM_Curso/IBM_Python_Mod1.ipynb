# %% [markdown]
# # Curso de IBM

# %% [markdown]
# ## First Program

# %%
print('Hello Python')
# Out:
# Hello Python

# %%
print("Hello\nWorld!")
# Out:
# Hello
# World!

# %%
# print('Hello World!')

# %% [markdown]
# ## Python Type

# %%
type(int(1.0))
# Out:
# int

# %%
bool(1)
# Out:
# True

# %% [markdown]
# ## Expressions and Variables

# %% [markdown]
# ## Expressions and Variables

# %%
x, y, z = ["hola", 24, 50.1]
type(x)
type(y)
type(z)
# Out:
# float

# %% [markdown]
# How would you obtain even numbers?

# %%
 Numbers = "0123456"
Numbers[::3]
# Out:
# '036'

# %%
Numbers[::2]
# Out:
# '0246'

# %%
Numbers[::6]
# Out:
# '06'

# %%
"0123456".find('1')
# Out:
# 1

# %% [markdown]
# ## String Operations

# %%
 3 + 2 * 2
# Out:
# 7

# %%
name = 'Lizz'
print(name[0:2])
# Out:
# Li

# %%
var = '01234567'
print(var[::2])
# Out:
# 0246

# %%
myvar = 'hello'
myvar.upper()
# Out:
# 'HELLO'
